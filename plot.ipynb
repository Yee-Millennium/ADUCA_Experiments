# %%
import matplotlib.pyplot as plt
import numpy as np

def plot_optmeasures(data1, data2, data3, optval):
    iterations_1 = np.array(data1['iterations'])
    optmeasures_1 = np.array(data1['optmeasures']) - optval
    iterations_2 = np.array(data2['iterations'])
    optmeasures_2 = np.array(data2['optmeasures']) - optval
    iterations_3 = np.array(data3['iterations'])
    optmeasures_3 = np.array(data3['optmeasures']) - optval

    fig, ax1 = plt.subplots(figsize=(8,8))
    fig.set_dpi(150)
    ax1.set_yscale('log')

    ax1.plot(iterations_1, optmeasures_1, marker='.', linestyle='-.', color='b', label = data1['args']['algo'])
    ax1.plot(iterations_2, optmeasures_2, marker='.', linestyle=':', color ='r', label = data2['args']['algo'])
    ax1.plot(iterations_3, optmeasures_3, marker='.', linestyle='-.', color ='g', label = data3['args']['algo'])
    
    ax1.set_xlabel('Full Gradient Evaluations')
    ax1.set_ylabel(r'$f - f^*$')
    ax1.set_title(f"dataset: {data1['args']['dataset']}")

    fig.savefig(f"output/{data1['args']['dataset']}")

    plt.grid(True)
    plt.legend()
    plt.show()

# %%
### SUSY (18,5000000)

import json

# Load the JSON data
# output/a9a-0.0_0.0-AdapCODER-0.0-output-2024-08-12_04-42-11-488756.json (small constants)
# output/a9a-0.0_0.0-AdapCODER-0.0-output-2024-08-12_04-53-24-733206.json (large)
with open('output/SUSY-0.0_0.0-AdapCODER_two_point-0.0-output-2024-09-18_02-09-35-760410.json') as f1:
    data1 = json.load(f1)
with open('output/SUSY-0.0_0.0-CODER_linesearch-0.0-output-2024-09-18_02-04-47-664207.json') as f2:
    data2 = json.load(f2)
with open('output/SUSY-0.0_0.0-GR-0.0-output-2024-09-18_02-16-23-833082.json') as f3:
    data3 = json.load(f3)


plot_optmeasures(data1, data2, data3, optval=0.37534612974501597)

# %%
### skin_nonskin (3, 245057)

import json

# Load the JSON data
# output/a9a-0.0_0.0-AdapCODER-0.0-output-2024-08-12_04-42-11-488756.json (small constants)
# output/a9a-0.0_0.0-AdapCODER-0.0-output-2024-08-12_04-53-24-733206.json (large)
with open('output/skin_nonskin-0.0_0.0-AdapCODER_two_point-0.0-output-2024-09-18_00-36-55-296298.json') as f1:
    data1 = json.load(f1)
with open('output/skin_nonskin-0.0_0.0-CODER_linesearch-0.0-output-2024-09-18_00-36-10-899812.json') as f2:
    data2 = json.load(f2)
with open('output/skin_nonskin-0.0_0.0-GR-0.0-output-2024-09-18_00-46-35-111333.json') as f3:
    data3 = json.load(f3)


plot_optmeasures(data1, data2, data3, optval=0.002859627758219943)

# %%
### mushrooms (112, 8124)
import json

# Load the JSON data
# output/a9a-0.0_0.0-AdapCODER-0.0-output-2024-08-12_04-42-11-488756.json (small constants)
# output/a9a-0.0_0.0-AdapCODER-0.0-output-2024-08-12_04-53-24-733206.json (large)
with open('output/mushrooms-0.0_0.0-AdapCODER_two_point-1.0-output-2024-09-18_03-28-26-440755.json') as f1:
    data1 = json.load(f1)
with open('output/mushrooms-0.0_0.0-CODER_linesearch-1.0-output-2024-09-18_03-28-55-544661.json') as f2:
    data2 = json.load(f2)
with open('output/mushrooms-0.0_0.0-GR-1.0-output-2024-09-18_03-30-04-186375.json') as f3:
    data3 = json.load(f3)


plot_optmeasures(data1, data2, data3, optval=0)

# %%
### phishing (68, 11055)
import json

# Load the JSON data
# output/a9a-0.0_0.0-AdapCODER-0.0-output-2024-08-12_04-42-11-488756.json (small constants)
# output/a9a-0.0_0.0-AdapCODER-0.0-output-2024-08-12_04-53-24-733206.json (large)
with open('output/phishing-0.0_0.0-AdapCODER_two_point-0.0-output-2024-09-18_00-23-35-878757.json') as f1:
    data1 = json.load(f1)
with open('output/phishing-0.0_0.0-CODER_linesearch-0.0-output-2024-09-18_00-24-44-573424.json') as f2:
    data2 = json.load(f2)
with open('output/phishing-0.0_0.0-GR-1.0-output-2024-09-18_03-32-00-197463.json') as f3:
    data3 = json.load(f3)


plot_optmeasures(data1, data2, data3, optval=0.307104015412267)

# %%
### a1a (123, 1605)

import json

# Load the JSON data
# output/a9a-0.0_0.0-AdapCODER-0.0-output-2024-08-12_04-42-11-488756.json (small constants)
# output/a9a-0.0_0.0-AdapCODER-0.0-output-2024-08-12_04-53-24-733206.json (large)
with open('output/a1a-0.0_0.0-AdapCODER_two_point-0.0-output-2024-09-19_02-26-03-679126.json') as f1:
    data1 = json.load(f1)
with open('output/a1a-0.0_0.0-CODER_linesearch-0.0-output-2024-09-19_02-21-25-625842.json') as f2:
    data2 = json.load(f2)
with open('output/a1a-0.0_0.0-GR-0.0-output-2024-09-19_02-21-00-819823.json') as f3:
    data3 = json.load(f3)


plot_optmeasures(data1, data2, data3, optval=0.31311653)

# %%
### a9a (123, 32561)

import json

# Load the JSON data
# output/a9a-0.0_0.0-AdapCODER-0.0-output-2024-08-12_04-42-11-488756.json (small constants)
# output/a9a-0.0_0.0-AdapCODER-0.0-output-2024-08-12_04-53-24-733206.json (large)
with open('output/a9a-0.0_0.0-AdapCODER_two_point-0.0-output-2024-09-19_02-24-59-939293.json') as f1:
    data1 = json.load(f1)
with open('output/a9a-0.0_0.0-CODER_linesearch-0.0-output-2024-09-19_02-21-38-880545.json') as f2:
    data2 = json.load(f2)
with open('output/a9a-0.0_0.0-GR-0.0-output-2024-09-19_02-24-39-617138.json') as f3:
    data3 = json.load(f3)


plot_optmeasures(data1, data2, data3, optval=0.324082)

# %%
### gisette_scale: (5000, 6000)

import json

# Load the JSON data
# output/a9a-0.0_0.0-AdapCODER-0.0-output-2024-08-12_04-42-11-488756.json (small constants)
# output/a9a-0.0_0.0-AdapCODER-0.0-output-2024-08-12_04-53-24-733206.json (large)
with open('output/gisette_scale-0.0_0.0-AdapCODER_two_point-0.0-output-2024-09-18_00-15-17-045182.json') as f1:
    data1 = json.load(f1)
with open('output/gisette_scale-0.0_0.0-CODER_linesearch-0.0-output-2024-09-18_00-08-04-499366.json') as f2:
    data2 = json.load(f2)

iterations_1 = np.array(data1['iterations'])
optmeasures_1 = np.array(data1['optmeasures']) 
iterations_2 = np.array(data2['iterations'])
optmeasures_2 = np.array(data2['optmeasures'])


fig, ax1 = plt.subplots(figsize=(8,8))
fig.set_dpi(150)
ax1.set_yscale('log')

ax1.plot(iterations_1, optmeasures_1, marker='.', linestyle='-.', color='b', label = data1['args']['algo'])
ax1.plot(iterations_2, optmeasures_2, marker='.', linestyle=':', color ='r', label = data2['args']['algo'])

ax1.set_xlabel('Full Gradient Evaluations')
ax1.set_ylabel(r'$f$')
ax1.set_title(f"dataset: {data1['args']['dataset']}")

fig.savefig(f"output/{data1['args']['dataset']}")

plt.grid(True)
plt.legend()
plt.show()
